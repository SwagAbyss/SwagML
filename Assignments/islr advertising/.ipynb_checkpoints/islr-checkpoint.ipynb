# %% [markdown]
# # __1. Import Packages__

# %%
# Data manipulation
import pandas as pd
import numpy as np
# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from scipy import stats
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
raw_data = pd.read_csv('./Advertising.csv')

# %% [markdown]
# # __2. Dataset Overview__

# %%
raw_data.head()
# Out:
#    ID     TV  Radio  Newspaper  Sales
# 0   1  230.1   37.8       69.2   22.1
# 1   2   44.5   39.3       45.1   10.4
# 2   3   17.2   45.9       69.3    9.3
# 3   4  151.5   41.3       58.5   18.5
# 4   5  180.8   10.8       58.4   12.9

# %% [markdown]
# __'Sales' column will be the dependent variable and the rest of the columns wii be considered as independent variable.__

# %%
raw_data = raw_data.drop(columns=['ID'])

# %%
raw_data.shape
# Out:
# (200, 4)

# %% [markdown]
# __This dataset contains 200 rows and 4 columns.__

# %% [markdown]
# #### __Dataset Basic Information:__

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# #### __Descriptions of Numerical Column:__

# %%
raw_data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# ## __3. Data Preprocessing__

# %%
data = raw_data.copy(deep=True)

# %%
numcols = data.select_dtypes(np.number)

# %% [markdown]
# #### __3.1 Missing values__

# %%
# Missing values

data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
# visualize missing values with seaborn (distplot)

plt.figure(figsize = (10, 4))
sns.displot(
    data = data.isna().melt(value_name = "missing"),
    x = "variable",
    hue = "missing",
    multiple = "fill",
    aspect = 2
)
plt.show()

# %% [markdown]
# __There is no missing value in the dataset.__

# %% [markdown]
# ####  __3.2 Duplicated Values__

# %%
# Duplicated values

data.duplicated().any()
# Out:
# False

# %% [markdown]
# #### __3.3 Finding Outliers in the dataset__

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10,6), dpi=200)
axes = axes.flat
for index, column in enumerate(numcols):
    graph = sns.boxplot(
        data=data, 
        x=column, 
        color=(list(plt.rcParams['axes.prop_cycle']))[index]['color'],
        ax=axes[index]
)
    axes[index].set_title(column, size=12)
    axes[index].set_xlabel('')
plt.suptitle('Outliers in every column', fontsize=20)
plt.tight_layout()

# %%
# finding Outliers

def outliers_zscore(data):
    data = sorted(data)

    mean = np.mean(data)

    std  = np.std(data)

    outliers = []
    for i, value in enumerate(data):
        zscore = (value - mean)/std
        if zscore > 3:
            outliers.append(i)
    return outliers

# %%
# finding outliers in every column

for column in data.columns:
    index = list(outliers_zscore(data[column]))
    data = data.drop(index)

# %% [markdown]
# #### __3.4 Finding Skewness__

# %%
from scipy.stats import skew
for col in numcols:
    print("Skewness of", col, "variable is:", data[col].skew())
# Out:
# Skewness of TV variable is: -0.05766635653947347
# Skewness of Radio variable is: 0.09436966577389365
# Skewness of Newspaper variable is: 0.9078455165572291
# Skewness of Sales variable is: 0.3972161502609735

# %% [markdown]
# ## __4. Exploratory Data Analysis__

# %% [markdown]
# ### __4.1 Univariate Analysis__

# %% [markdown]
# #### __4.1.1 Distribution of every single numerical column__

# %%
sns.set_style('darkgrid')
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
axes = axes.flat
for index, column in enumerate(numcols):
    graph = sns.histplot(
        data = data,
        x    = column,
        stat = 'count',
        kde  = True,
        color   = (list(plt.rcParams['axes.prop_cycle'])*2)[index]['color'],
        line_kws= {'linewidth': 4},
        alpha   = 0.5,
        ax      = axes[index]
)
    for p in graph.patches:
        axes[index].annotate(
            f'{p.get_height()}',
            (p.get_x() + p.get_width() / 2, p.get_height() + 1),
            ha='center',
            fontsize=10,
            fontweight="bold",
        )
    axes[index].set_title(column, fontsize = 10)
    axes[index].tick_params(labelsize = 8)
    axes[index].set_xlabel('')
plt.suptitle('Distribution of Numerical Variables', fontsize=15)
plt.tight_layout()

# %% [markdown]
# ### __4.2 Bivariate Analysis__
# #### __4.2.1 Target vs Numerical Features__

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(10,5), dpi=200)
axes =axes.flat
numfeatures = ['TV', 'Radio', 'Newspaper']
target = 'Sales'
for index, column in enumerate(numfeatures):
    graph = sns.scatterplot(
        x=data[column],
        y=data[target],
        linewidths=0.25,
        color=(list(plt.rcParams['axes.prop_cycle'])*2)[index]['color'],
        ax=axes[index]
)
    axes[index].set_title(f'{column} vs {target}', fontsize=12)
    axes[index].set_xlabel(column, size=12)
    axes[index].set_ylabel(target, size=12)
    axes[index].grid()

plt.suptitle('Sales vs Numerical Features', size=20)
plt.tight_layout()

# %% [markdown]
# #### __4.3 Relation between dependent and independant variables__

# %%
plt.figure(figsize=(10,3))
plt.scatter(data.TV, data.Sales, color='blue', label="TV")
plt.scatter(data.Radio, data.Sales, color='green', label='Radio')
plt.scatter(data.Newspaper, data.Sales, color='red', label='Newspaper')
plt.xlabel("TV|Radio|Newspaper")
plt.ylabel('Sales')
plt.title("Relation between dependent and independant variables")
plt.legend()
plt.show()

# %% [markdown]
# #### __4.4 Pairplot for the dataset__

# %%
plt.figure(figsize=(10,6))
sns.pairplot(data, diag_kind='kde')
plt.suptitle('Pairplot', size=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### __4.5 Correlation Analysis__

# %%
data.corr().style.background_gradient('plasma')
# Out:
# <style type="text/css">
# #T_0e530_row0_col0, #T_0e530_row1_col1, #T_0e530_row2_col2, #T_0e530_row3_col3 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_0e530_row0_col1, #T_0e530_row0_col2, #T_0e530_row1_col0, #T_0e530_row2_col0, #T_0e530_row2_col3 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# #T_0e530_row0_col3 {
#   background-color: #f58b47;
#   color: #f1f1f1;
# }
# #T_0e530_row1_col2, #T_0e530_row2_col1 {
#   background-color: #9410a2;
#   color: #f1f1f1;
# }
# #T_0e530_row1_col3 {
#   background-color: #c03a83;
#   color: #f1f1f1;
# }
# #T_0e530_row3_col0 {
#   background-color: #fa9c3c;
#   color: #000000;
# }
# #T_0e530_row3_col1 {
#   background-color: #d6556d;
#   color: #f1f1f1;
# }
# #T_0e530_row3_col2 {
#   background-color: #6001a6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0e530">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e530_level0_col0" class="col_heading level0 col0" >TV</th>
#       <th id="T_0e530_level0_col1" class="col_heading level0 col1" >Radio</th>
#       <th id="T_0e530_level0_col2" class="col_heading level0 col2" >Newspaper</th>
#       <th id="T_0e530_level0_col3" class="col_heading level0 col3" >Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e530_level0_row0" class="row_heading level0 row0" >TV</th>
#       <td id="T_0e530_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_0e530_row0_col1" class="data row0 col1" >0.050396</td>
#       <td id="T_0e530_row0_col2" class="data row0 col2" >0.049418</td>
#       <td id="T_0e530_row0_col3" class="data row0 col3" >0.781641</td>
#     </tr>
#     <tr>
#       <th id="T_0e530_level0_row1" class="row_heading level0 row1" >Radio</th>
#       <td id="T_0e530_row1_col0" class="data row1 col0" >0.050396</td>
#       <td id="T_0e530_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_0e530_row1_col2" class="data row1 col2" >0.344151</td>
#       <td id="T_0e530_row1_col3" class="data row1 col3" >0.572381</td>
#     </tr>
#     <tr>
#       <th id="T_0e530_level0_row2" class="row_heading level0 row2" >Newspaper</th>
#       <td id="T_0e530_row2_col0" class="data row2 col0" >0.049418</td>
#       <td id="T_0e530_row2_col1" class="data row2 col1" >0.344151</td>
#       <td id="T_0e530_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_0e530_row2_col3" class="data row2 col3" >0.214180</td>
#     </tr>
#     <tr>
#       <th id="T_0e530_level0_row3" class="row_heading level0 row3" >Sales</th>
#       <td id="T_0e530_row3_col0" class="data row3 col0" >0.781641</td>
#       <td id="T_0e530_row3_col1" class="data row3 col1" >0.572381</td>
#       <td id="T_0e530_row3_col2" class="data row3 col2" >0.214180</td>
#       <td id="T_0e530_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Using heatmap to find correlation
plt.figure(figsize=(10,6))
sns.heatmap(
    data.corr(), 
    annot=True, 
    cmap='crest', 
    linewidth=True
)
plt.suptitle('Correlation in heatmap', size=30)
# Out:
# Text(0.5, 0.98, 'Correlation in heatmap')

# %% [markdown]
#  - __The target variable 'Sales' is highly correlated with 'TV' and 'Radio'.__

# %% [markdown]
# ## __5. Build Linear Regression Model__

# %% [markdown]
# ### __5.1 Determine Features & Target Variables__

# %%
X = data.drop(columns='Sales')
y = data.Sales

# %% [markdown]
# ### __5.2 Split the dataset into Traing and Test sets__

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(X, y, random_state=True, train_size=0.8)

# %%
print('xtrain shape: ', xtrain.shape)
print('xtest shape: ', xtest.shape)
print('ytrain shape: ', ytrain.shape)
print('ytest shape: ',ytest.shape)
# Out:
# xtrain shape:  (158, 3)
# xtest shape:  (40, 3)
# ytrain shape:  (158,)
# ytest shape:  (40,)

# %% [markdown]
# ### __5.3 Scale data using StandardScaler__

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
scale.fit(xtrain)
xtrain_scaled = scale.transform(xtrain)
xtest_scaled = scale.transform(xtest)

# %% [markdown]
# __It is very important that StandardScaler transformation should only be learnt from the training set, otherwise it will lead to data leakage.__

# %% [markdown]
# ### __5.4 Train the Model__

# %%
from sklearn.linear_model import LinearRegression
linear_reg = LinearRegression()
linear_reg.fit(xtrain_scaled, ytrain)
# Out:
# LinearRegression()
