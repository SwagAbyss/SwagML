# %% [markdown]
# # __1. Import Packages__

# %%
# Data manipulation
import pandas as pd
import numpy as np
# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from scipy.stats import skew
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
raw_data = pd.read_csv('./winequality-red.csv', sep=';')

# %% [markdown]
# # __2. Dataset Overview__

# %%
raw_data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
raw_data.shape
# Out:
# (1599, 12)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
raw_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %% [markdown]
# # __3. Exploratory Data Analysis__

# %%
data = raw_data.copy(deep=True)

# %%
features = data.drop(columns=['quality']).columns
target = data['quality']

# %% [markdown]
# ## __3.1 Missing values__

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# __There is no missing values present in this dataset.__

# %% [markdown]
# ##  __3.2 Duplicated Values__

# %%
data.duplicated().sum()
# Out:
# 240

# %% [markdown]
# __There are 240 duplicated values present in this dataset.__

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (1359, 12)

# %% [markdown]
# ## __3.3 Finding outliers in the dataset__

# %%
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(20,15), dpi=200)
axes = axes.flat
sns.set_style("whitegrid")
for index, column in enumerate(data):
    graph = sns.boxplot(
        data=data, 
        x=column, 
        palette='Accent',
        ax=axes[index]
)
    axes[index].set_title(column, size=12)
    axes[index].set_xlabel('')
plt.suptitle('Outliers in every column', fontsize=20)
plt.tight_layout()

# %% [markdown]
# __There are so many outliers in this dataset.__

# %% [markdown]
# ## __3.4 Distribution of continuos variables__

# %%
sns.set_style('darkgrid')
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(20,10))
axes = axes.flat
for index, column in enumerate(data):
    graph = sns.histplot(
        data = data,
        x    = column,
        stat = 'count',
        kde  = True,
        color   = (list(plt.rcParams['axes.prop_cycle'])*2)[index]['color'],
        line_kws= {'linewidth': 2},
        alpha   = 0.7,
        ax      = axes[index]
)

    axes[index].set_title(column, fontsize = 10)
    axes[index].tick_params(labelsize = 8)
    axes[index].set_xlabel('')
plt.suptitle('Distribution of Continuos Variables', fontsize=15)
plt.tight_layout()

# %% [markdown]
# __Density and pH are the only column normally distributed in the dataset.__
# __Other variables are highly skewed.__

# %% [markdown]
# ## __3.5 Skewness of Continuous Variables__

# %%
skew = {}
for col in features:
    skewness = data[col].skew()
    skew[col]=skewness
    print(f"Skewness of {col}: {skewness}")
# Out:
# Skewness of fixed acidity: 0.9410413664561449
# Skewness of volatile acidity: 0.7292789463991854
# Skewness of citric acid: 0.31272554238899036
# Skewness of residual sugar: 4.548153403940447
# Skewness of chlorides: 5.502487294623722
# Skewness of free sulfur dioxide: 1.2265794991760643
# Skewness of total sulfur dioxide: 1.5403680777213933
# Skewness of density: 0.04477785573116107
# Skewness of pH: 0.2320322752014824
# Skewness of sulphates: 2.4065046145674196
# Skewness of alcohol: 0.8598411692032926

# %%
plt.figure(figsize=(18,9))
sns.barplot(x=list(skew.keys()), y=list(skew.values()), saturation=2)
plt.title("Skewness of Continuous Variables", fontsize=30)
plt.show()

# %% [markdown]
# __Sulphates, Residual sugar and Chlorides are the highly skewed variables.__

# %%
skew = {}
for col in features:
    skewness = np.log(data[col]).skew()
    skew[col]=skewness
    print(f"Skewness of {col}: {skewness}")
# Out:
# Skewness of fixed acidity: 0.3488037361098303
# Skewness of volatile acidity: -0.3307953869456426
# Skewness of citric acid: nan
# Skewness of residual sugar: 1.7652376788280852
# Skewness of chlorides: 1.8876423282330907
# Skewness of free sulfur dioxide: -0.22006917758574188
# Skewness of total sulfur dioxide: -0.07816071342785713
# Skewness of density: 0.03683872065905041
# Skewness of pH: 0.03976372242209134
# Skewness of sulphates: 0.9614602293854239
# Skewness of alcohol: 0.6633592527469497

# %% [markdown]
# __using np.log we can handle skewness in the dataset.__

# %%
for col in data[features]:
    data[col] = np.log(data[col])

# %%
plt.figure(figsize=(18,9))
sns.barplot(x=list(skew.keys()), y=list(skew.values()), saturation=2)
plt.title("Skewness of Continuous Variables", fontsize=30)
plt.show()

# %% [markdown]
# __Now we handled the skewness in the dataset.__

# %% [markdown]
# ### __Distribution of the data after handled the skewness__

# %%
sns.set_style('darkgrid')
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(20,10))
axes = axes.flat
for index, column in enumerate(data):
    graph = sns.histplot(
        data = data,
        x    = column,
        stat = 'count',
        kde  = True,
        color   = (list(plt.rcParams['axes.prop_cycle'])*2)[index]['color'],
        line_kws= {'linewidth': 2},
        alpha   = 0.7,
        ax      = axes[index]
)

    axes[index].set_title(column, fontsize = 10)
    axes[index].tick_params(labelsize = 8)
    axes[index].set_xlabel('')
plt.suptitle('Distribution of Continuos Variables', fontsize=15)
plt.tight_layout()

# %% [markdown]
# ## __3.6 Kurtosis of continuos variables__

# %%
kurt = {}
for col in data.columns:
    kurtosis = data[col].kurt()
    kurt[col]=kurtosis
    print(f"Kurtosis of {col}: {kurtosis}")
# Out:
# Kurtosis of fixed acidity: 0.0791568203998767
# Kurtosis of volatile acidity: 0.047137346643409295
# Kurtosis of citric acid: nan
# Kurtosis of residual sugar: 4.869054720647114
# Kurtosis of chlorides: 8.656165894923285
# Kurtosis of free sulfur dioxide: -0.5246857107550431
# Kurtosis of total sulfur dioxide: -0.6914357406563889
# Kurtosis of density: 0.8291703764894107
# Kurtosis of pH: 0.708783526267486
# Kurtosis of sulphates: 2.1139717385780146
# Kurtosis of alcohol: -0.3171752270642778
# Kurtosis of quality: 0.3402560880620915

# %%
plt.figure(figsize=(18,9))
sns.barplot(x=list(kurt.keys()), y=list(kurt.values()), saturation=2)
plt.title("Kurtosis of Continuous Variables", fontsize=30)
plt.show()

# %% [markdown]
# __Sulphates, Residual sugar and Chlorides are the high kurtosis values.__

# %% [markdown]
# ## __3.7 Correlation between numerical features__

# %%
data.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_48237_row0_col0, #T_48237_row1_col1, #T_48237_row2_col2, #T_48237_row3_col3, #T_48237_row4_col4, #T_48237_row5_col5, #T_48237_row6_col6, #T_48237_row7_col7, #T_48237_row8_col8, #T_48237_row9_col9, #T_48237_row10_col10, #T_48237_row11_col11 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_48237_row0_col1, #T_48237_row5_col3 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_48237_row0_col2 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_48237_row0_col3, #T_48237_row4_col8 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_48237_row0_col4, #T_48237_row11_col8 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_48237_row0_col5, #T_48237_row0_col8, #T_48237_row1_col2, #T_48237_row1_col9, #T_48237_row1_col11, #T_48237_row2_col1, #T_48237_row7_col10, #T_48237_row8_col0, #T_48237_row8_col3, #T_48237_row10_col4, #T_48237_row10_col6, #T_48237_row10_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_48237_row0_col6, #T_48237_row1_col3 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_48237_row0_col7 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_48237_row0_col9 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_48237_row0_col10, #T_48237_row1_col6, #T_48237_row5_col10 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_48237_row0_col11, #T_48237_row2_col4, #T_48237_row3_col8 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_48237_row1_col0, #T_48237_row6_col9 {
#   background-color: #cdd0e5;
#   color: #000000;
# }
# #T_48237_row1_col4 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_48237_row1_col5 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_48237_row1_col7, #T_48237_row7_col1 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_48237_row1_col8 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_48237_row1_col10, #T_48237_row9_col5 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_48237_row2_col0 {
#   background-color: #0872b1;
#   color: #f1f1f1;
# }
# #T_48237_row2_col3, #T_48237_row2_col6, #T_48237_row3_col5, #T_48237_row7_col8, #T_48237_row8_col5, #T_48237_row11_col7 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_48237_row2_col5, #T_48237_row8_col9 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_48237_row2_col7, #T_48237_row10_col8 {
#   background-color: #62a2cb;
#   color: #f1f1f1;
# }
# #T_48237_row2_col8 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_48237_row2_col9, #T_48237_row9_col7 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_48237_row2_col10 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_48237_row2_col11, #T_48237_row6_col7 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_48237_row3_col0 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_48237_row3_col1, #T_48237_row10_col0 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_48237_row3_col2 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_48237_row3_col4, #T_48237_row9_col8 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_48237_row3_col6, #T_48237_row5_col7 {
#   background-color: #bbc7e0;
#   color: #000000;
# }
# #T_48237_row3_col7 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_48237_row3_col9, #T_48237_row5_col4 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_48237_row3_col10, #T_48237_row6_col1, #T_48237_row6_col8 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_48237_row3_col11, #T_48237_row5_col2, #T_48237_row6_col4 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_48237_row4_col0 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_48237_row4_col1 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_48237_row4_col2, #T_48237_row7_col3 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_48237_row4_col3, #T_48237_row8_col6 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_48237_row4_col5 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_48237_row4_col6 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_48237_row4_col7 {
#   background-color: #569dc8;
#   color: #f1f1f1;
# }
# #T_48237_row4_col9, #T_48237_row9_col10 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_48237_row4_col10 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_48237_row4_col11, #T_48237_row7_col11 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_48237_row5_col0 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_48237_row5_col1, #T_48237_row6_col2, #T_48237_row7_col9 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_48237_row5_col6 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_48237_row5_col8, #T_48237_row11_col9 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_48237_row5_col9 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_48237_row5_col11 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_48237_row6_col0 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_48237_row6_col3 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_48237_row6_col5 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_48237_row6_col10, #T_48237_row6_col11 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_48237_row7_col0 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_48237_row7_col2 {
#   background-color: #60a1ca;
#   color: #f1f1f1;
# }
# #T_48237_row7_col4 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_48237_row7_col5 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_48237_row7_col6 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_48237_row8_col1 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_48237_row8_col2 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_48237_row8_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_48237_row8_col7 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_48237_row8_col10 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_48237_row8_col11 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_48237_row9_col0 {
#   background-color: #63a2cb;
#   color: #f1f1f1;
# }
# #T_48237_row9_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_48237_row9_col2 {
#   background-color: #69a5cc;
#   color: #f1f1f1;
# }
# #T_48237_row9_col3 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_48237_row9_col4 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_48237_row9_col6 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_48237_row9_col11 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_48237_row10_col1 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_48237_row10_col2 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_48237_row10_col3 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_48237_row10_col5 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_48237_row10_col9 {
#   background-color: #b5c4df;
#   color: #000000;
# }
# #T_48237_row10_col11 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_48237_row11_col0 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_48237_row11_col1 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_48237_row11_col2 {
#   background-color: #88b1d4;
#   color: #000000;
# }
# #T_48237_row11_col3, #T_48237_row11_col4, #T_48237_row11_col5 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_48237_row11_col6 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_48237_row11_col10 {
#   background-color: #2a88bc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_48237">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48237_level0_col0" class="col_heading level0 col0" >fixed acidity</th>
#       <th id="T_48237_level0_col1" class="col_heading level0 col1" >volatile acidity</th>
#       <th id="T_48237_level0_col2" class="col_heading level0 col2" >citric acid</th>
#       <th id="T_48237_level0_col3" class="col_heading level0 col3" >residual sugar</th>
#       <th id="T_48237_level0_col4" class="col_heading level0 col4" >chlorides</th>
#       <th id="T_48237_level0_col5" class="col_heading level0 col5" >free sulfur dioxide</th>
#       <th id="T_48237_level0_col6" class="col_heading level0 col6" >total sulfur dioxide</th>
#       <th id="T_48237_level0_col7" class="col_heading level0 col7" >density</th>
#       <th id="T_48237_level0_col8" class="col_heading

# %%
data.corr()['quality']
# Out:
# fixed acidity           0.108135
# volatile acidity       -0.393354
# citric acid             0.175124
# residual sugar          0.021653
# chlorides              -0.181196
# free sulfur dioxide    -0.046420
# total sulfur dioxide   -0.163977
# density                -0.184493
# pH                     -0.055091
# sulphates               0.308728
# alcohol                 0.481473
# quality                 1.000000
# Name: quality, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data.corr(), annot=True)
plt.title("Correlation", size=20)
# Out:
# Text(0.5, 1.0, 'Correlation')

# %% [markdown]
# __Alcohol, Volatile acidity, Sulphates are the variables that have highly correlated with the target data.__

# %% [markdown]
# # __4. Feature Engineering__

# %% [markdown]
# - Drop unwanted Features
# - Handle Missing Values
# - Handle Categorical Features
# - Handle Feature Scalling
# - Remove Outliers

# %% [markdown]
# ## __4.1 Drop unwanted Features__

# %%
data = data.drop(columns=['residual sugar', 'free sulfur dioxide'])

# %% [markdown]
# ## __4.2 Handle Missing Values__

# %% [markdown]
# __There is no missing data present in this dataset.__

# %% [markdown]
# ## __4.3 Handle Categorical Features__

# %% [markdown]
# ## __4.4 Handle Feature Scalling__

# %% [markdown]
# ## __4.5 Remove Outliers__

# %% [markdown]
# # __5. Build Linear Regression Model__

# %% [markdown]
# ## __5.1 Determine Features & Target Variables__

# %%
X = data.drop(columns='Sales')
y = data.Sales

# %% [markdown]
# ## __5.2 Split the dataset into Traing and Test sets__

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(X, y, random_state=True, train_size=0.8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [8], line 3
#       1 from sklearn.model_selection import train_test_split
# ----> 3 xtrain, xtest, ytrain, ytest = train_test_split(X, y, random_state=True, train_size=0.8)
#
# NameError: name 'X' is not defined

# %%
print('xtrain shape: ', xtrain.shape)
print('xtest shape: ', xtest.shape)
print('ytrain shape: ', ytrain.shape)
print('ytest shape: ',ytest.shape)

# %% [markdown]
# ## __5.3 Scale data using RobustScaler__

# %%
from sklearn.preprocessing import RobustScaler
scale = RobustScaler()
scale.fit(xtrain)
xtrain = scale.transform(xtrain)
xtest = scale.transform(xtest)

# %% [markdown]
# ## __5.4 Train the Model__

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain, ytrain)
ypred = model.predict(xtest)

# %%
pd.DataFrame(
    data=np.append(model.intercept_, model.coef_),
    index=['Intercept'] + [f"{col} coef." for col in X.columns],
    columns=['Value']
).sort_values('Value', ascending=False)

# %% [markdown]
# ## __5.5 Model Evaluation__

# %% [markdown]
# trainacc = model.score(xtrain, ytrain)
# testacc = model.score(xtest, ytest)
#
# pd.DataFrame([trainacc*100, testacc*100], index=['Train Accuracy', 'Test Accuracy'], columns=['Value'])

# %%
from sklearn import metrics
def model_evaluation(model, xtest, ytest, model_name):
    ypred = model.predict(xtest)

    MAE = metrics.mean_absolute_error(ytest, ypred)
    MSE = metrics.mean_squared_error(ytest, ypred)
    RMSE = np.sqrt(MSE)
    R2_Score = metrics.r2_score(ytest, ypred)

    return pd.DataFrame(
        [MAE, MSE, RMSE, R2_Score],
        index=['MAE', 'MSE', 'RMSE', 'R2-Score'],
        columns=[model_name],
    )

# %% [markdown]
# model_evaluation(model, xtest, ytest, 'Linear Regression')

# %%
df_compare = pd.DataFrame({'Actual':ytest, 'Predicted':ypred}).reset_index(drop=True)
df_compare.head()

# %%
def compare_plot(data):
    data.plot(y=['Actual', 'Predicted'], kind='bar', figsize=(10,6), width=0.8)
    plt.title('Predicted vs. Actual Target Values for Test Data', fontsize=20)
    plt.ylabel('Selling_Price', fontsize=15)
    plt.show()

# %%
sns.regplot(x=ytest, y=ypred)
plt.xlabel("Actual")
plt.ylabel("Predicted")

# %%
compare_plot(df_compare)

# %% [markdown]
# __The difference between the corresponding bars in the above bar plot shows the prediction error of the model on the test data.__
