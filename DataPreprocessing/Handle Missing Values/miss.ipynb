# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../data/loan_data.csv')
data1 = pd.read_csv('../data/Titanic-Dataset.csv')

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
data['ApplicantIncome'].isnull().any()
# Out:
# False

# %%
data['CoapplicantIncome'].dtypes
# Out:
# dtype('float64')

# %%
for column in data.columns:
    if data[column].isnull().any()==True:
        print(column, data[column].isna().sum(), data[column].dtype, (data[column].isnull().sum()/len(data)*100))
# Out:
# Gender 13 object 2.1172638436482085
# Married 3 object 0.4885993485342019
# Dependents 15 object 2.44299674267101
# Self_Employed 32 object 5.211726384364821
# LoanAmount 22 float64 3.5830618892508146
# Loan_Amount_Term 14 float64 2.2801302931596092
# Credit_History 50 float64 8.143322475570033

# %%
data['Gender'].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
c = data['Gender'].mode()

# %%
data['Gender'].fillna(value=c)
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 609    Female
# 610      Male
# 611      Male
# 612      Male
# 613    Female
# Name: Gender, Length: 614, dtype: object

# %%
round(data['LoanAmount'].mean(), 2)
# Out:
# 146.41

# %%
data['LoanAmount'].fillna(value=146.41)
# Out:
# 0      146.41
# 1      128.00
# 2       66.00
# 3      120.00
# 4      141.00
#         ...
# 609     71.00
# 610     40.00
# 611    253.00
# 612    187.00
# 613    133.00
# Name: LoanAmount, Length: 614, dtype: float64

# %%
from sklearn.impute import SimpleImputer
object_impute = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
object_impute.fit_transform(data[['Gender']])

object_impute1 = SimpleImputer(missing_values=np.nan, strategy='constant', fill_value='Male')
object_impute1.fit_transform(data[['Gender']])
# Out:
# array([['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Female'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Female'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Female'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Male'],
#        ['Female'],
#        ['Male'],
#        ['Male'],
#        ['Female'],
#        ['Female'],
#        ['Female'],
# ...

# %%
mean_impute = SimpleImputer(missing_values=np.nan, strategy='mean')

mean_impute.fit_transform(data[['LoanAmount']]).astype('int64')
# Out:
# array([[146],
#        [128],
#        [ 66],
#        [120],
#        [141],
#        [267],
#        [ 95],
#        [158],
#        [168],
#        [349],
#        [ 70],
#        [109],
#        [200],
#        [114],
#        [ 17],
#        [125],
#        [100],
#        [ 76],
#        [133],
#        [115],
#        [104],
#        [315],
#        [116],
#        [112],
#        [151],
#        [191],
#        [122],
#        [110],
#        [ 35],
#        [120],
#        [201],
#        [ 74],
#        [106],
#        [114],
#        [320],
#        [146],
#        [100],
#        [144],
#        [184],
#        [110],
#        [ 80],
#        [ 47],
#        [ 75],
#        [134],
#        [ 96],
#        [ 88],
#        [ 44],
#        [144],
#        [120],
#        [144],
#        [100],
#        [120],
#        [112],
#        [134],
#        [286],
#        [ 97],
#        [ 96],
#        [135],
#        [180],
#        [144],
#        [120],
#        [ 99],
# ...

# %%
mean_impute = SimpleImputer(missing_values=np.nan, strategy='median')

mean_impute.fit_transform(data[['LoanAmount']]).astype('int64')
# Out:
# array([[128],
#        [128],
#        [ 66],
#        [120],
#        [141],
#        [267],
#        [ 95],
#        [158],
#        [168],
#        [349],
#        [ 70],
#        [109],
#        [200],
#        [114],
#        [ 17],
#        [125],
#        [100],
#        [ 76],
#        [133],
#        [115],
#        [104],
#        [315],
#        [116],
#        [112],
#        [151],
#        [191],
#        [122],
#        [110],
#        [ 35],
#        [120],
#        [201],
#        [ 74],
#        [106],
#        [114],
#        [320],
#        [128],
#        [100],
#        [144],
#        [184],
#        [110],
#        [ 80],
#        [ 47],
#        [ 75],
#        [134],
#        [ 96],
#        [ 88],
#        [ 44],
#        [144],
#        [120],
#        [144],
#        [100],
#        [120],
#        [112],
#        [134],
#        [286],
#        [ 97],
#        [ 96],
#        [135],
#        [180],
#        [144],
#        [120],
#        [ 99],
# ...

# %%
from sklearn.impute import KNNImputer

knn_imputer = KNNImputer(n_neighbors=7, weights='distance')

knn_imputer.fit_transform(data[['LoanAmount']])
# Out:
# array([[146.41216216],
#        [128.        ],
#        [ 66.        ],
#        [120.        ],
#        [141.        ],
#        [267.        ],
#        [ 95.        ],
#        [158.        ],
#        [168.        ],
#        [349.        ],
#        [ 70.        ],
#        [109.        ],
#        [200.        ],
#        [114.        ],
#        [ 17.        ],
#        [125.        ],
#        [100.        ],
#        [ 76.        ],
#        [133.        ],
#        [115.        ],
#        [104.        ],
#        [315.        ],
#        [116.        ],
#        [112.        ],
#        [151.        ],
#        [191.        ],
#        [122.        ],
#        [110.        ],
#        [ 35.        ],
#        [120.        ],
#        [201.        ],
#        [ 74.        ],
#        [106.        ],
#        [114.        ],
#        [320.        ],
#        [146.41216216],
#        [100.        ],
#        [144.        ],
#        [184.        ],
#        [110.        ],
# ...
