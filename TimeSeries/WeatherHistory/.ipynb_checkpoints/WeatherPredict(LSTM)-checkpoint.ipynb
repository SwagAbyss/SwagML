# %% [markdown]
# # __Import Packages__

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# plt.style.use('fivethirtyeight')

# %% [markdown]
# # __Data Overview__

# %%
raw_data = pd.read_csv('./weatherHistory.csv')

# %%
raw_data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# 1                   259.0          15.8263         0.0               1015.63
# 2                   204.0          14.9569         0.0               1015.94
# 3                   269.0          15.8263         0.0               1016.41
# 4                   259.0          15.8263         0.0               1016.51
#
#                        Daily Summary
# 0  Partly cloudy throughout the day.
# 1  Partly cloudy throughout the day.
# 2  Partly cloudy throughout the day.
# 3  Partly cloudy throughout the day.
# 4  Partly cloudy throughout the day.

# %%
raw_data.tail()
# Out:
#                       Formatted Date        Summary Precip Type  \
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96448        26.016667                 26.016667      0.43            10.9963
# 96449        24.583333                 24.583333      0.48            10.0947
# 96450        22.038889                 22.038889      0.56             8.9838
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 96448                    31.0          16.1000         0.0
# 96449                    20.0          15.5526         0.0
# 96450                    30.0          16.1000         0.0
# 96451                    20.0          16.1000         0.0
# 96452                    39.0          15.5204         0.0
#
#        Pressure (millibars)                           Daily Summary
# 96448               1014.36  Partly cloudy starting in the morning.
# 96449               1015.16  Partly cloudy starting in the morning.
# 96450               1015.66  Partly cloudy starting in the morning.
# 96451               1015.95  Partly cloudy starting in the morning.
# 96452               1016.16  Partly cloudy starting in the morning.

# %%
raw_data.shape
# Out:
# (96453, 12)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %% [markdown]
# - This Datset Contains 96543 rows and 12 columns
# - Categorical variables have data type object.
#
# - Numerical variables have data type float64

# %%
raw_data.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# 25%             5.828200              116.000000         8.339800         0.0
# 50%             9.965900              180.000000        10.046400         0.0
# 75%            14.135800              290.000000        14.812000         0.0
# max            63.852600              359.000000        16.100000         0.0
#
#        Pressure (millibars)
# count          96453.000000
# mean            1003.235956
# std              116.969906
# min                0.000000
# 25%             1011.900000
# 50%             1016.450000
# 75%             1021.090000
# max             1046.380000

# %% [markdown]
# # __Data Preperation__

# %%
data = raw_data.copy(deep=True)

# %%
data.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
data.columns = data.columns.str.replace(' ', '_')

# %%
data.drop(columns='Loud_Cover', inplace=True)

# %%
data['Formatted_Date'] = pd.to_datetime(data['Formatted_Date'], format='%Y-%m-%d', utc=True)

# %%
data.set_index('Formatted_Date', inplace=True)

# %% [markdown]
# # __Exploratory Data Analysis__

# %% [markdown]
# ## __Handling Missing Values__

# %%
data.isnull().sum()
# Out:
# Summary                       0
# Precip_Type                 517
# Temperature_(C)               0
# Apparent_Temperature_(C)      0
# Humidity                      0
# Wind_Speed_(km/h)             0
# Wind_Bearing_(degrees)        0
# Visibility_(km)               0
# Pressure_(millibars)          0
# Daily_Summary                 0
# dtype: int64

# %%
data['Precip_Type'].unique()
# Out:
# array(['rain', 'snow', nan], dtype=object)

# %%
missing_df = data[data.isnull().any(axis=1)]
missing_df.head()
# Out:
#                                  Summary Precip_Type  Temperature_(C)  \
# Formatted_Date
# 2012-04-11 14:00:00+00:00  Mostly Cloudy         NaN        19.016667
# 2012-04-11 16:00:00+00:00  Mostly Cloudy         NaN        17.850000
# 2012-04-11 17:00:00+00:00  Mostly Cloudy         NaN        16.322222
# 2012-04-11 19:00:00+00:00  Mostly Cloudy         NaN        12.566667
# 2012-04-11 20:00:00+00:00  Mostly Cloudy         NaN        12.927778
#
#                            Apparent_Temperature_(C)  Humidity  \
# Formatted_Date
# 2012-04-11 14:00:00+00:00                 19.016667      0.26
# 2012-04-11 16:00:00+00:00                 17.850000      0.28
# 2012-04-11 17:00:00+00:00                 16.322222      0.32
# 2012-04-11 19:00:00+00:00                 12.566667      0.43
# 2012-04-11 20:00:00+00:00                 12.927778      0.47
#
#                            Wind_Speed_(km/h)  Wind_Bearing_(degrees)  \
# Formatted_Date
# 2012-04-11 14:00:00+00:00            14.8764                   163.0
# 2012-04-11 16:00:00+00:00            13.7977                   169.0
# 2012-04-11 17:00:00+00:00            10.8192                   151.0
# 2012-04-11 19:00:00+00:00             9.0160                   159.0
# 2012-04-11 20:00:00+00:00            17.6295                   197.0
#
#                            Visibility_(km)  Pressure_(millibars)  \
# Formatted_Date
# 2012-04-11 14:00:00+00:00            9.982               1002.40
# 2012-04-11 16:00:00+00:00            9.982               1001.79
# 2012-04-11 17:00:00+00:00            9.982               1001.60
# 2012-04-11 19:00:00+00:00            9.982               1001.92
# 2012-04-11 20:00:00+00:00           16.100               1002.20
#
#                                         Daily_Summary
# Formatted_Date
# 2012-04-11 14:00:00+00:00  Mostly cloudy until night.
# 2012-04-11 16:00:00+00:00  Mostly cloudy until night.
# 2012-04-11 17:00:00+00:00  Mostly cloudy until night.
# 2012-04-11 19:00:00+00:00  Mostly cloudy until night.
# 2012-04-11 20:00:00+00:00  Mostly cloudy until night.

# %%
missing_df.min()
# Out:
# Summary                                         Clear
# Precip_Type                                      None
# Temperature_(C)                              1.255556
# Apparent_Temperature_(C)                    -0.822222
# Humidity                                         0.26
# Wind_Speed_(km/h)                              1.0787
# Wind_Bearing_(degrees)                            0.0
# Visibility_(km)                                   0.0
# Pressure_(millibars)                           993.94
# Daily_Summary               Clear throughout the day.
# dtype: object

# %%
data.groupby(by='Precip_Type').min()
# Out:
#             Summary  Temperature_(C)  Apparent_Temperature_(C)  Humidity  \
# Precip_Type
# rain         Breezy         0.005556                 -7.550000       0.0
# snow         Breezy       -21.822222                -27.716667       0.0
#
#              Wind_Speed_(km/h)  Wind_Bearing_(degrees)  Visibility_(km)  \
# Precip_Type
# rain                       0.0                     0.0              0.0
# snow                       0.0                     0.0              0.0
#
#              Pressure_(millibars)                              Daily_Summary
# Precip_Type
# rain                          0.0  Breezy and foggy starting in the evening.
# snow                          0.0  Breezy and foggy starting in the evening.

# %%
data['Precip_Type'].fillna('rain', inplace=True)

# %%
data.isnull().sum()
# Out:
# Summary                     0
# Precip_Type                 0
# Temperature_(C)             0
# Apparent_Temperature_(C)    0
# Humidity                    0
# Wind_Speed_(km/h)           0
# Wind_Bearing_(degrees)      0
# Visibility_(km)             0
# Pressure_(millibars)        0
# Daily_Summary               0
# dtype: int64

# %% [markdown]
# ### Drop Unwanted Columns

# %%
fig, axes = plt.subplots(ncols=2, nrows=3, figsize=(15, 20))
axes = axes.flat
number_cols = ['Temperature_(C)', 'Humidity', 'Wind_Speed_(km/h)', 
               'Wind_Bearing_(degrees)', 'Visibility_(km)', 'Pressure_(millibars)']
for index, column in enumerate(number_cols):
    sns.barplot(
        data=data, 
        x='Summary', 
        y=column, 
        hue='Precip_Type', 
        palette='Set2',
        ax=axes[index]

    )
    plt.setp(axes[index].get_xticklabels(), rotation=90)
plt.suptitle('Numerical vs Summary')
plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# ### Resampling the Data
#
# ##### Downsampling:
# 1. Downsampling is the process of reducing the frequency of the time series data by aggregating or summarizing the data over longer time intervals.
# - For example, you can downsample daily data to weekly data by computing the mean or median of the daily data over each week. Downsampling can be useful for reducing the amount of data and noise in the time series and can also speed up computational time.
#
# ##### Upsampling:
# 1. Upsampling is the process of increasing the frequency of the time series data by interpolating the data over shorter time intervals.
# - For example, you can upsample weekly data to daily data by interpolating or filling in missing values for the daily data using the values from the weekly data. Upsampling can be useful for capturing more detailed patterns in the time series data or for aligning different time series data with different frequencies.
#
# ##### Code for resampling the data:
# `df.resample(‘desired need(frequency)’).aggregate_function()`
#
# frequency ('S' : Seconds, 'T' : Minute, 'H' : Hour, 'D' : Day, 'M' : Month, 'Q' : Quarter Year, 'Y' : Year)

# %%
data = data.resample('D').apply(lambda x :x.mode()[0])

# %% [markdown]
# ## __Univariate Analysis__

# %%
data.nunique()
# Out:
# Summary                       14
# Precip_Type                    2
# Temperature_(C)             1849
# Apparent_Temperature_(C)    2386
# Humidity                      86
# Wind_Speed_(km/h)            865
# Wind_Bearing_(degrees)       305
# Visibility_(km)              261
# Pressure_(millibars)        2049
# Daily_Summary                214
# dtype: int64

# %%
fig, axes = plt.subplots(ncols=1, nrows=7, figsize=(15, 25))
axes = axes.flat
number_cols = ['Temperature_(C)', 'Apparent_Temperature_(C)', 'Humidity',
       'Wind_Speed_(km/h)', 'Wind_Bearing_(degrees)', 'Visibility_(km)',
       'Pressure_(millibars)']
colors = ['red', 'green', 'pink']
for index, column in enumerate(number_cols):
    sns.lineplot(
        data[column].shift(1),
        color=(list(plt.rcParams['axes.prop_cycle'])*2)[index]['color'],
        ax=axes[index]

    )

plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# ### __Target Distribution__

# %%
weather_summary = data['Summary'].value_counts().reset_index()
weather_summary.columns = ['Weather', 'Counts']
weather_summary
# Out:
#                      Weather  Counts
# 0              Partly Cloudy    1463
# 1              Mostly Cloudy    1291
# 2                   Overcast     670
# 3                      Clear     298
# 4                      Foggy     267
# 5        Breezy and Overcast      13
# 6   Breezy and Mostly Cloudy       6
# 7   Breezy and Partly Cloudy       3
# 8    Windy and Partly Cloudy       2
# 9                 Light Rain       2
# 10          Breezy and Foggy       1
# 11                    Breezy       1
# 12                   Drizzle       1
# 13                      Rain       1

# %% [markdown]
# ### __Continuos Numerical Feature Distribution__

# %%
data.select_dtypes(include=np.number).columns
# Out:
# Index(['Temperature_(C)', 'Apparent_Temperature_(C)', 'Humidity',
#        'Wind_Speed_(km/h)', 'Wind_Bearing_(degrees)', 'Visibility_(km)',
#        'Pressure_(millibars)'],
#       dtype='object')

# %%
fig, axes = plt.subplots(ncols=3, nrows=2, figsize=(15, 10))
axes = axes.flat
number_cols = ['Temperature_(C)', 'Humidity', 'Wind_Speed_(km/h)', 
               'Wind_Bearing_(degrees)', 'Visibility_(km)', 'Pressure_(millibars)']
for index, column in enumerate(number_cols):
    sns.histplot(
        data=data, 
        x=column,
        kde=True,
        color=(list(plt.rcParams['axes.prop_cycle'])*2)[index]['color'],
        ax=axes[index]

    )
#     plt.setp(axes[index].get_xticklabels(), rotation=90)
plt.suptitle('Distrbution of Numerical Columns')
plt.tight_layout(pad=2)
plt.show()

# %%
fig, axes = plt.subplots(ncols=3, nrows=2, figsize=(15, 10))
axes = axes.flat
number_cols = ['Temperature_(C)', 'Humidity', 'Wind_Speed_(km/h)', 
               'Wind_Bearing_(degrees)', 'Visibility_(km)', 'Pressure_(millibars)']
for index, column in enumerate(number_cols):
    sns.boxplot(
        data=data, 
        x=column,
#         kde=True,
        color=(list(plt.rcParams['axes.prop_cycle'])*2)[index]['color'],
        ax=axes[index]

    )
#     plt.setp(axes[index].get_xticklabels(), rotation=90)
plt.suptitle('Distrbution of Numerical Columns')
plt.tight_layout(pad=2)
plt.show()

# %% [markdown]
# ## __Bivariate Analysis__

# %%
fig, axes = plt.subplots(ncols=2, nrows=3, figsize=(15, 20))
axes = axes.flat
number_cols = ['Temperature_(C)', 'Humidity', 'Wind_Speed_(km/h)', 
               'Wind_Bearing_(degrees)', 'Visibility_(km)', 'Pressure_(millibars)']
for index, column in enumerate(number_cols):
    sns.barplot(
        data=data, 
        x='Summary', 
        y=column, 
        hue='Precip_Type', 
        palette='Set2',
        ax=axes[index]

    )
    plt.setp(axes[index].get_xticklabels(), rotation=90)
plt.suptitle('Numerical vs Summary')
plt.tight_layout(pad=2)
plt.show()

# %%
sns.pairplot(data, hue='Summary')

# %%
from sklearn.preprocessing import OrdinalEncoder
encoder = OrdinalEncoder()
data[['Precip_Type', 'Summary']] = encoder.fit_transform(data[['Precip_Type', 'Summary']])

# %%
data.corr(numeric_only=True).style.background_gradient(cmap='magma')
# Out:
# <style type="text/css">
# #T_b53bb_row0_col0, #T_b53bb_row1_col1, #T_b53bb_row2_col2, #T_b53bb_row3_col3, #T_b53bb_row4_col4, #T_b53bb_row5_col5, #T_b53bb_row6_col6, #T_b53bb_row7_col7, #T_b53bb_row8_col8 {
#   background-color: #fcfdbf;
#   color: #000000;
# }
# #T_b53bb_row0_col1, #T_b53bb_row5_col3, #T_b53bb_row6_col5 {
#   background-color: #4c117a;
#   color: #f1f1f1;
# }
# #T_b53bb_row0_col2 {
#   background-color: #a5317e;
#   color: #f1f1f1;
# }
# #T_b53bb_row0_col3, #T_b53bb_row4_col1 {
#   background-color: #aa337d;
#   color: #f1f1f1;
# }
# #T_b53bb_row0_col4 {
#   background-color: #440f76;
#   color: #f1f1f1;
# }
# #T_b53bb_row0_col5, #T_b53bb_row5_col0 {
#   background-color: #19103f;
#   color: #f1f1f1;
# }
# #T_b53bb_row0_col6 {
#   background-color: #160f3b;
#   color: #f1f1f1;
# }
# #T_b53bb_row0_col7 {
#   background-color: #ab337c;
#   color: #f1f1f1;
# }
# #T_b53bb_row0_col8 {
#   background-color: #150e38;
#   color: #f1f1f1;
# }
# #T_b53bb_row1_col0, #T_b53bb_row1_col2, #T_b53bb_row1_col3, #T_b53bb_row1_col6, #T_b53bb_row2_col4, #T_b53bb_row3_col1, #T_b53bb_row3_col5, #T_b53bb_row4_col7, #T_b53bb_row6_col8, #T_b53bb_row8_col6 {
#   background-color: #000004;
#   color: #f1f1f1;
# }
# #T_b53bb_row1_col4 {
#   background-color: #982d80;
#   color: #f1f1f1;
# }
# #T_b53bb_row1_col5 {
#   background-color: #2f1163;
#   color: #f1f1f1;
# }
# #T_b53bb_row1_col7 {
#   background-color: #02020d;
#   color: #f1f1f1;
# }
# #T_b53bb_row1_col8, #T_b53bb_row4_col2 {
#   background-color: #08071e;
#   color: #f1f1f1;
# }
# #T_b53bb_row2_col0, #T_b53bb_row3_col0 {
#   background-color: #651a80;
#   color: #f1f1f1;
# }
# #T_b53bb_row2_col1 {
#   background-color: #020109;
#   color: #f1f1f1;
# }
# #T_b53bb_row2_col3 {
#   background-color: #fde0a1;
#   color: #000000;
# }
# #T_b53bb_row2_col5, #T_b53bb_row3_col6 {
#   background-color: #040414;
#   color: #f1f1f1;
# }
# #T_b53bb_row2_col6, #T_b53bb_row7_col4 {
#   background-color: #050416;
#   color: #f1f1f1;
# }
# #T_b53bb_row2_col7 {
#   background-color: #c43c75;
#   color: #f1f1f1;
# }
# #T_b53bb_row2_col8, #T_b53bb_row4_col0 {
#   background-color: #06051a;
#   color: #f1f1f1;
# }
# #T_b53bb_row3_col2 {
#   background-color: #fddea0;
#   color: #000000;
# }
# #T_b53bb_row3_col4 {
#   background-color: #03030f;
#   color: #f1f1f1;
# }
# #T_b53bb_row3_col7 {
#   background-color: #c03a76;
#   color: #f1f1f1;
# }
# #T_b53bb_row3_col8 {
#   background-color: #0a0822;
#   color: #f1f1f1;
# }
# #T_b53bb_row4_col3, #T_b53bb_row8_col5 {
#   background-color: #140e36;
#   color: #f1f1f1;
# }
# #T_b53bb_row4_col5 {
#   background-color: #221150;
#   color: #f1f1f1;
# }
# #T_b53bb_row4_col6 {
#   background-color: #07061c;
#   color: #f1f1f1;
# }
# #T_b53bb_row4_col8 {
#   background-color: #030312;
#   color: #f1f1f1;
# }
# #T_b53bb_row5_col1 {
#   background-color: #812581;
#   color: #f1f1f1;
# }
# #T_b53bb_row5_col2 {
#   background-color: #51127c;
#   color: #f1f1f1;
# }
# #T_b53bb_row5_col4 {
#   background-color: #621980;
#   color: #f1f1f1;
# }
# #T_b53bb_row5_col6 {
#   background-color: #2c115f;
#   color: #f1f1f1;
# }
# #T_b53bb_row5_col7 {
#   background-color: #54137d;
#   color: #f1f1f1;
# }
# #T_b53bb_row5_col8 {
#   background-color: #010005;
#   color: #f1f1f1;
# }
# #T_b53bb_row6_col0, #T_b53bb_row8_col0 {
#   background-color: #341069;
#   color: #f1f1f1;
# }
# #T_b53bb_row6_col1, #T_b53bb_row8_col7 {
#   background-color: #681c81;
#   color: #f1f1f1;
# }
# #T_b53bb_row6_col2 {
#   background-color: #6e1e81;
#   color: #f1f1f1;
# }
# #T_b53bb_row6_col3 {
#   background-color: #721f81;
#   color: #f1f1f1;
# }
# #T_b53bb_row6_col4 {
#   background-color: #601880;
#   color: #f1f1f1;
# }
# #T_b53bb_row6_col7, #T_b53bb_row8_col4 {
#   background-color: #5c167f;
#   color: #f1f1f1;
# }
# #T_b53bb_row7_col0 {
#   background-color: #862781;
#   color: #f1f1f1;
# }
# #T_b53bb_row7_col1, #T_b53bb_row7_col5 {
#   background-color: #20114b;
#   color: #f1f1f1;
# }
# #T_b53bb_row7_col2 {
#   background-color: #d5446d;
#   color: #f1f1f1;
# }
# #T_b53bb_row7_col3 {
#   background-color: #d6456c;
#   color: #f1f1f1;
# }
# #T_b53bb_row7_col6 {
#   background-color: #0d0a29;
#   color: #f1f1f1;
# }
# #T_b53bb_row7_col8 {
#   background-color: #180f3d;
#   color: #f1f1f1;
# }
# #T_b53bb_row8_col1 {
#   background-color: #762181;
#   color: #f1f1f1;
# }
# #T_b53bb_row8_col2 {
#   background-color: #701f81;
#   color: #f1f1f1;
# }
# #T_b53bb_row8_col3 {
#   background-color: #792282;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b53bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b53bb_level0_col0" class="col_heading level0 col0" >Summary</th>
#       <th id="T_b53bb_level0_col1" class="col_heading level0 col1" >Precip_Type</th>
#       <th id="T_b53bb_level0_col2" class="col_heading level0 col2" >Temperature_(C)</th>
#       <th id="T_b53bb_level0_col3" class="col_heading level0 col3" >Apparent_Temperature_(C)</th>
#       <th id="T_b53bb_level0_col4" class="col_heading level0 col4" >Humidity</th>
#       <th id="T_b53bb_level0_col5" class="col_heading level0 col5" >Wind_Speed_(km/h)</th>
#       <th id="T_b53bb_level0_col6" class="col_heading level0 col6" >Wind_Bearing_(degrees)</th>
#       <th id="T_b53bb_level0_col7" class="col_heading level0 col7" >Visibility_(km)</th>
#       <th id="T_b53bb_level0_col8" class="col_heading level0 col8" >Pressure_(millibars)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b53bb_level0_row0" class="row_heading level0 row0" >Summary</th>
#       <td id="T_b53bb_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b53bb_row0_col1" class="data row0 col1" >-0.155821</td>
#       <td id="T_b53bb_row0_col2" class="data row0 col2" >0.193780</td>
#       <td id="T_b53bb_row0_col3" class="data row0 col3" >0.195858</td>
#       <td id="T_b53bb_row0_col4" class="data row0 col4" >-0.097802</td>
#       <td id="T_b53bb_row0_col5" class="data row0 col5" >-0.023434</td>
#       <td id="T_b53bb_row0_col6" class="data row0 col6" >0.059229</td>
#       <td id="T_b53bb_row0_col7" class="data row0 col7" >0.290608</td>
#       <td id="T_b53bb_row0_col8" class="data row0 col8" >0.058254</td>
#     </tr>
#     <tr>
#       <th id="T_b53bb_level0_row1" class="row_heading level0 row1" >Precip_Type</th>
#       <td id="T_b53bb_row1_col0" class="data row1 col0" >-0.155821</td>
#       <td id="T_b53bb_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b53bb_row1_col2" class="data row1 col2" >-0.493465</td>
#       <td id="T_b53bb_row1_col3" class="data row1 col3" >-0.522607</td>
#       <td id="T_b53bb_row1_col4" class="data row1 col4" >0.196637</td>
#       <td id="T_b53bb_row1_col5" class="data row1 col5" >0.044591</td>
#       <td id="T_b53bb_row1_col6" class="data row1 col6" >-0.050053</td>
#       <td id="T_b53bb_row1_col7" class="data row1 col7" >-0.317034</td>
#       <td id="T_b53bb_row1_col8" class="data row1 col8" >0.006499</td>
#     </tr>
#     <tr>
#       <th id="T_b53bb_level0_row2" class="row_heading level0 row2" >Temperature_(C)</th>
#       <td id="T_b53bb_row2_col0" class="data row2 col0" >0.193780</td>
#       <td id="T_b53bb_row2_col1" class="data row2 col1" >-0.493465</td>
#       <td id="T_b53bb_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b53bb_row2_col3" class="data row2 col3" >0.899769</td>
#       <td id="T_b53bb_row2_col4" class="data row2 col4" >-0.407969</td>
#       <td id="T_b53bb_row2_col5" class="data row2 col5" >-0.115027</td>
#       <td id="T_b53bb_row2_col6" class="data row2 col6" >-0.007078</td>
#       <td id="T_b53bb_row2_col7" class="data row2 col7" >0.367114</td>
#       <td id="T_b53bb_row2_col8" class="data row2 col8" >-0.000496</td>
#     </tr>
#     <tr>
#       <th id="T_b53bb_level0_row3" class="row_heading level0 row3" >Apparent_Temperature_(C)</th>
#       <td id="T_b53bb_row3_col0" class="data row3 col0" >0.195858</td>
#       <td id="T_b53bb_row3_col1" class="data row3 col1" >-0.522607</td>
#       <td id="T_b53bb_row3_col2" class="data row3 col2" >0.899769</td>
#       <td id="T_b53bb_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_b53bb_row3_col4" class="data row3 col4" >-0.369025</td>
#       <td id="T_b53bb_row3_col5" class="data row3 col5" >-0.157588</td>
#       <td id="T_b53bb_row3_col6" class="data row3 col6" >-0.011596</td>
#       <td id="T_b53bb_row3_col7" class="data row3 col7" >0.360984</td>

# %%
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap='magma')
# Out:
# <Axes: >

# %% [markdown]
# ## __Feature Engineering__

# %% [markdown]
# ### __Drop Unwanted Columns__

# %%
data.columns
# Out:
# Index(['Summary', 'Precip_Type', 'Temperature_(C)', 'Apparent_Temperature_(C)',
#        'Humidity', 'Wind_Speed_(km/h)', 'Wind_Bearing_(degrees)',
#        'Visibility_(km)', 'Pressure_(millibars)', 'Daily_Summary'],
#       dtype='object')

# %%
data.drop(columns=['Temperature_(C)', 'Wind_Bearing_(degrees)', 'Pressure_(millibars)', 'Daily_Summary'], inplace=True)

# %%
data
# Out:
#                            Summary  Precip_Type  Apparent_Temperature_(C)  \
# Formatted_Date
# 2005-12-31 00:00:00+00:00     11.0          0.0                 -4.050000
# 2006-01-01 00:00:00+00:00      9.0          0.0                 -3.272222
# 2006-01-02 00:00:00+00:00     10.0          0.0                 -3.116667
# 2006-01-03 00:00:00+00:00     10.0          0.0                  2.244444
# 2006-01-04 00:00:00+00:00     10.0          0.0                 -2.738889
# ...                            ...          ...                       ...
# 2016-12-27 00:00:00+00:00      9.0          0.0                 -5.533333
# 2016-12-28 00:00:00+00:00      9.0          1.0                 -5.588889
# 2016-12-29 00:00:00+00:00      9.0          1.0                 -5.638889
# 2016-12-30 00:00:00+00:00      9.0          1.0                 -5.688889
# 2016-12-31 00:00:00+00:00      9.0          1.0                 -5.694444
#
#                            Humidity  Wind_Speed_(km/h)  Visibility_(km)
# Formatted_Date
# 2005-12-31 00:00:00+00:00      0.89            17.1143           9.9820
# 2006-01-01 00:00:00+00:00      0.86            13.6689           9.9015
# 2006-01-02 00:00:00+00:00      0.80             2.4150           4.4919
# 2006-01-03 00:00:00+00:00      0.89             1.7388           9.5795
# 2006-01-04 00:00:00+00:00      0.92            17.3880          11.1251
# ...                             ...                ...              ...
# 2016-12-27 00:00:00+00:00      0.83             9.5795           3.6547
# 2016-12-28 00:00:00+00:00      0.83             9.5795           3.6547
# 2016-12-29 00:00:00+00:00      0.83             9.4990           8.0178
# 2016-12-30 00:00:00+00:00      0.83             8.8872           8.0178
# 2016-12-31 00:00:00+00:00      0.83             8.8711           3.6708
#
# [4019 rows x 6 columns]

# %% [markdown]
# ### __Differencing the data__

# %%
def series_to_supervised(data, nlag_in=1, nlag_out=1, dropna=True):
        
        ncols = 1 if data is list() else data.shape[1]
        df = pd.DataFrame(data) 
        col_names, col_values = [], []
        
        # Create lagged input sequence data
        for i in range(nlag_in, 0, -1):
            col_values.append(data.shift(i))
            
            for j in range(ncols):
                col_names.append(f'col{j+i}(t-{i})')
                
        # Create forecast output sequence data
        for i in range(0, nlag_out):
            col_values.append(data.shift(-i))
            for j in range(ncols):
                if i==0:
                    col_names.append(f'col{j+1}(t)')
                else:
                    col_names.append(f'col{j+1}(t-{i})')
                    
        # Saving and converting the col_names and col_values into dataframe
        final_df = pd.concat(col_values, axis=1)
        final_df.columns = col_names
        
        # Drop the rows with missing values
        if dropna is True:
            final_df.dropna(inplace=True)
                
        return final_df

# %%
data = series_to_supervised(data)

# %%
data.head()
# Out:
#                            col1(t-1)  col2(t-1)  col3(t-1)  col4(t-1)  \
# Formatted_Date
# 2006-01-01 00:00:00+00:00       11.0        0.0  -4.050000       0.89
# 2006-01-02 00:00:00+00:00        9.0        0.0  -3.272222       0.86
# 2006-01-03 00:00:00+00:00       10.0        0.0  -3.116667       0.80
# 2006-01-04 00:00:00+00:00       10.0        0.0   2.244444       0.89
# 2006-01-05 00:00:00+00:00       10.0        0.0  -2.738889       0.92
#
#                            col5(t-1)  col6(t-1)  col1(t)  col2(t)   col3(t)  \
# Formatted_Date
# 2006-01-01 00:00:00+00:00    17.1143     9.9820      9.0      0.0 -3.272222
# 2006-01-02 00:00:00+00:00    13.6689     9.9015     10.0      0.0 -3.116667
# 2006-01-03 00:00:00+00:00     2.4150     4.4919     10.0      0.0  2.244444
# 2006-01-04 00:00:00+00:00     1.7388     9.5795     10.0      0.0 -2.738889
# 2006-01-05 00:00:00+00:00    17.3880    11.1251     10.0      0.0 -0.572222
#
#                            col4(t)  col5(t)  col6(t)
# Formatted_Date
# 2006-01-01 00:00:00+00:00     0.86  13.6689   9.9015
# 2006-01-02 00:00:00+00:00     0.80   2.4150   4.4919
# 2006-01-03 00:00:00+00:00     0.89   1.7388   9.5795
# 2006-01-04 00:00:00+00:00     0.92  17.3880  11.1251
# 2006-01-05 00:00:00+00:00     0.92   2.6887   4.2021

# %%
data.drop(data.iloc[:, 7:], axis=1, inplace=True)

# %% [markdown]
# ## __Build the Model__

# %%
x = data.drop(columns='col1(t)').values
y = data['col1(t)'].values

# %%
x[:3650, :]
# Out:
# 3650

# %%
xtrain = x[:3650]
ytrain = y[:3650]
xtest =
